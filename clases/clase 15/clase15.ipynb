# %%
# prompt: from google colab import drive
# drive.mount("/drive")

from google.colab import drive
drive.mount("/drive")

ruta = "/content/sample_data"

f=open(ruta + "/ejemplo.txt", "w")
f.write("hola chicos este es un texto que modifique desde colab2")
f.close()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
nombre = "Nicolas"
apellido = "Perez"
dni = 11222333

d ={"Nombre": nombre, "Apellido":apellido, "DNI": dni}

f=open(ruta + "/ejemplo2.txt", "w")
f.write(d["Nombre"] + " " + d["Apellido"] + " " + str(d["DNI"]))
f.close()

# %%
#Crear un progrma y guardalo en un archivo .txt
#crea un programa que pida por teclado (input)
# los datos de tus tres hobbies favoritos
#y los mismos se guarden en un archivo que se llame miHobbieFavorito.txt

#extra: hacerlo con un for o un while para no repetir tanto

# Inicializar una lista para almacenar los hobbies
hobbies = []

# Usar un bucle while para solicitar los hobbies al usuario
i = 1
while i <= 3:
    hobbie = input(f"Ingrese su hobbie favorito número {i}: ")
    hobbies.append(hobbie)
    i += 1

# Escribir los hobbies en el archivo
f = open("/content/sample_data/miHobbieFavorito.txt", "w")
f.write("Mis hobbies favoritos son:\n")
for hobbie in hobbies:
    f.write(f"- {hobbie}\n")
f.close()

print("Los hobbies se han guardado en 'miHobbieFavorito.txt'")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-2f1ae324747c> in <cell line: 13>()
#      12 i = 1
#      13 while i <= 3:
# ---> 14     hobbie = input(f"Ingrese su hobbie favorito número {i}: ")
#      15     hobbies.append(hobbie)
#      16     i += 1
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
f = open("/content/sample_data/paraLeer.txt", "r")
content = f.read()
print(content)
f.close()
# Out:
# soy el primer renglon
# ahora soy el 2do renglon
# no sé ni que soy
# acá hay otro renglon
# soy el 5

# %%
f = open(ruta + "/paraLeer.txt", "r")

print(f.readline())


f.close()
# Out:
# soy el primer renglon

# %%
f = open(ruta + "/paraLeer.txt", "r")

for line in f.readlines():
    print(line)


f.close()
# Out:
# soy el primer renglon
#
# ahora soy el 2do renglon
#
# no sé ni que soy
#
# acá hay otro renglon
#
# soy el 5

# %%
f = open(ruta + "/paraLeer.txt", "r")

f.seek(20)

print(f.read())


f.close()
# Out:
# n
# ahora soy el 2do renglon
# no sé ni que soy
# acá hay otro renglon
# soy el 5

# %%
import json  #Importar las funciones de json en la
#clase 15 entenderemos mejor el IMPORT

data = {}

data['clients'] = []

data['clients'].append({
    'first_name': 'Sigrid',
    'last_name': 'Mannock',
    'age': 27,
    'amount': 7.17})

data['clients'].append({
    'first_name': 'Joe',
    'last_name': 'Hinners',
    'age': 31,
    'amount': [1.90, 5.50]})

data['clients'].append({
    'first_name': 'Theodoric',
    'last_name': 'Rivers',
    'age': 36,
    'amount': 1.11})

with open(ruta + "/primerJson.json", 'w') as file:
    json.dump(data, file, indent=4)

# %%
with open(ruta + "/primerJson.json") as file:

    dataLectura = json.load(file)

    for client in dataLectura['clients']:
        print('First name:', client['first_name'])
        print('Last name:', client['last_name'])
        print('Age:', client['age'])
        print('Amount:', client['amount'])
        print('')
# Out:
# First name: Sigrid
# Last name: Mannock
# Age: 27
# Amount: 7.17
#
# First name: Joe
# Last name: Hinners
# Age: 31
# Amount: [1.9, 5.5]
#
# First name: Theodoric
# Last name: Rivers
# Age: 36
# Amount: 1.11

# %%
#Con esto daremos permisos para acceder al Drive, es importante colocar el codigo de verificacion correspondiente

from google.colab import drive

import pandas as pd  #Importamos pandas para la lectura de datos y lo llamamos

import numpy as np  #Importamos numpy para el manejo de datos


#En mi caso voy a abrir los datos de listado de personal de arsat

variableTurnos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/listado-de-personal.csv")

#Acá se vé que era necesario tener pandas, ya que usamos la función read_csv de pandas.
#LISTO... Ya tenemos todos nuestros datos leidos y guardados en una variable... Ya son "facilmente" manipulables.
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-16f612fb6ec6> in <cell line: 12>()
#      10 #En mi caso voy a abrir los datos de listado de personal de arsat
#      11
# ---> 12 variableTurnos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/listado-de-personal.csv")
#      13
#      14 #Acá se vé que era necesario tener pandas, ya que usamos la función read_csv de pandas.
#
# ...

# %%
#En mi caso voy a abrir los datos de listado de personal de arsat

variableTurnos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/listado-de-personal.csv")

#Acá se vé que era necesario tener pandas, ya que usamos la función read_csv de pandas.
#LISTO... Ya tenemos todos nuestros datos leidos y guardados en una variable... Ya son "facilmente" manipulables.
